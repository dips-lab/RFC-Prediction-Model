# %%
#Importing the necessary libraries we will be using
# %load_ext autoreload
# %autoreload 2
# %matplotlib inline
from fastai.imports import *
from fastai.structured import *
from pandas_summary import DataFrameSummary
from sklearn.ensemble import RandomForestRegressor
from IPython.display import display
from sklearn import metrics
from sklearn.model_selection import RandomizedSearchCV
#Loading the Dataset
PATH = 'data/Boston Housing Dataset/'
df_raw_train = pd.read_csv(f'{PATH}train.csv',low_memory = False)
df_raw_test = pd.read_csv(f'{PATH}test.csv',low_memory = False)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-1-3ec68ca92f1d> in <module>
#       4 get_ipython().run_line_magic('matplotlib', 'inline')
#       5 from fastai.imports import *
# ----> 6 from fastai.structured import *
#       7 from pandas_summary import DataFrameSummary
#       8 from sklearn.ensemble import RandomForestRegressor
#
# ModuleNotFoundError: No module named 'fastai.structured'

# %%
pip install fastai==0.7.0
# Out:
# Collecting fastai==0.7.0
#   Downloading fastai-0.7.0-py3-none-any.whl (112 kB)
#      |████████████████████████████████| 112 kB 9.2 MB/s eta 0:00:01
# Collecting bcolz
#   Downloading bcolz-1.2.1.tar.gz (1.5 MB)
#      |████████████████████████████████| 1.5 MB 14.0 MB/s eta 0:00:01
# Requirement already satisfied: seaborn in /Users/Dips-Bootcamp/opt/anaconda3/envs/pyvizenv/lib/python3.8/site-packages (from fastai==0.7.0) (0.11.1)
# Requirement already satisfied: pyparsing in /Users/Dips-Bootcamp/opt/anaconda3/envs/pyvizenv/lib/python3.8/site-packages (from fastai==0.7.0) (2.4.7)
# Requirement already satisfied: decorator in /Users/Dips-Bootcamp/opt/anaconda3/envs/pyvizenv/lib/python3.8/site-packages (from fastai==0.7.0) (4.4.2)
# Requirement already satisfied: cycler in /Users/Dips-Bootcamp/opt/anaconda3/envs/pyvizenv/lib/python3.8/site-packages (from fastai==0.7.0) (0.10.0)
# Requirement already satisfied: scipy in /Users/Dips-Bootcamp/opt/anaconda3/envs/pyvizenv/lib/python3.8/site-packages (from fastai==0.7.0) (1.6.2)
# Requirement already satisfied: ipykernel in /Users/Dips-Bootcamp/opt/anaconda3/envs/pyvizenv/lib/python3.8/site-packages (from fastai==0.7.0) (5.3.4)
# Requirement already satisfied: jupyter in /Users/Dips-Bootcamp/opt/anaconda3/envs/pyvizenv/lib/python3.8/site-packages (from fastai==0.7.0) (1.0.0)
# Collecting pandas-summary
#   Downloading pandas_summary-0.0.7-py2.py3-none-any.whl (5.2 kB)
# Requirement already satisfied: MarkupSafe in /Users/Dips-Bootcamp/opt/anaconda3/envs/pyvizenv/lib/python3.8/site-packages (from fastai==0.7.0) (1.1.1)
# Requirement already satisfied: traitlets in /Users/Dips-Bootcamp/opt/anaconda3/envs/pyvizenv/lib/python3.8/site-packages (from fastai==0.7.0) (5.0.5)
# Requirement already satisfied: testpath in /Users/Dips-Bootcamp/opt/anaconda3/envs/pyvizenv/lib/python3.8/site-packages (from fastai==0.7.0) (0.4.4)
# Requirement already satisfied: PyYAML in /Users/Dips-Bootcamp/opt/anaconda3/envs/pyvizenv/lib/python3.8/site-packages (from fastai==0.7.0) (5.4.1)
# Requirement already satisfied: Pygments in /Users/Dips-Bootcamp/opt/anaconda3/envs/pyvizenv/lib/python3.8/site-packages (from fastai==0.7.0) (2.8.1)
# Requirement already satisfied: Pillow in /Users/Dips-Bootcamp/opt/anaconda3/envs/pyvizenv/lib/python3.8/site-packages (from fastai==0.7.0) (8.1.2)
# Collecting plotnine
#   Downloading plotnine-0.8.0-py3-none-any.whl (4.7 MB)
#      |████████████████████████████████| 4.7 MB 20.5 MB/s eta 0:00:01
# Requirement already satisfied: tornado in /Users/Dips-Bootcamp/opt/anaconda3/envs/pyvizenv/lib/python3.8/site-packages (from fastai==0.7.0) (6.1)
# Requirement already satisfied: ipywidgets in /Users/Dips-Bootcamp/opt/anaconda3/envs/pyvizenv/lib/python3.8/site-packages (from fastai==0.7.0) (7.6.3)
# Requirement already satisfied: simplegeneric in /Users/Dips-Bootcamp/opt/anaconda3/envs/pyvizenv/lib/python3.8/site-packages (from fastai==0.7.0) (0.8.1)
# Requirement already satisfied: entrypoints in /Users/Dips-Bootcamp/opt/anaconda3/envs/pyvizenv/lib/python3.8/site-packages (from fastai==0.7.0) (0.3)
# Requirement already satisfied: tqdm in /Users/Dips-Bootcamp/opt/anaconda3/envs/pyvizenv/lib/python3.8/site-packages (from fastai==0.7.0) (4.59.0)
# Requirement already satisfied: html5lib in /Users/Dips-Bootcamp/opt/anaconda3/envs/pyvizenv/lib/python3.8/site-packages (from fastai==0.7.0) (1.1)
# Requirement already satisfied: pytz in /Users/Dips-Bootcamp/opt/anaconda3/envs/pyvizenv/lib/python3.8/site-packages (from fastai==0.7.0) (2021.1)
# Requirement already satisfied: certifi in /Users/Dips-Bootcamp/opt/anaconda3/envs/pyvizenv/lib/python3.8/site-packages (from fastai==0.7.0) (2021.5.30)
# Requirement already satisfied: jedi in /Users/Dips-Bootcamp/opt/anaconda3/envs/pyvizenv/lib/python3.8/site-packages (from fastai==0.7.0) (0.17.1)
# Collecting sklearn-pandas
#   Downloading sklearn_pandas-2.2.0-py2.py3-none-any.whl (10 kB)
# Requirement already satisfied: torchvision in /Users/Dips-Bootcamp/opt/anaconda3/envs/pyvizenv/lib/python3.8/site-packages (from fastai==0.7.0) (0.10.0)
# Requirement already satisfied: python-dateutil in /Users/Dips-Bootcamp/opt/anaconda3/envs/pyvizenv/lib/python3.8/site-packages (from fastai==0.7.0) (2.8.1)
# Requirement already satisfied: graphviz in /Users/Dips-Bootcamp/opt/anaconda3/envs/pyvizenv/lib/python3.8/site-packages (from fastai==0.7.0) (0.16)
# Requirement already satisfied: matplotlib in /Users/Dips-Bootcamp/opt/anaconda3/envs/pyvizenv/lib/python3.8/site-packages (from fastai==0.7.0) (3.1.3)
# Collecting feather-format
#   Downloading feather-format-0.4.1.tar.gz (3.2 kB)
# Requirement already satisfied: webencodings in /Users/Dips-Bootcamp/opt/anaconda3/envs/pyvizenv/lib/python3.8/site-packages (from fastai==0.7.0) (0.5.1)
# Requirement already satisfied: bleach in /Users/Dips-Bootcamp/opt/anaconda3/envs/pyvizenv/lib/python3.8/site-packages (from fastai==0.7.0) (3.3.0)
# Requirement already satisfied: wcwidth in /Users/Dips-Bootcamp/opt/anaconda3/envs/pyvizenv/lib/python3.8/site-packages (from fastai==0.7.0) (0.2.5)
# Requirement already satisfied: ipython-genutils in /Users/Dips-Bootcamp/opt/anaconda3/envs/pyvizenv/lib/python3.8/site-packages (from fastai==0.7.0) (0.2.0)
# Requirement already satisfied: pandas in /Users/Dips-Bootcamp/opt/anaconda3/envs/pyvizenv/lib/python3.8/site-packages (from fastai==0.7.0) (1.2.4)
# Requirement already satisfied: widgetsnbextension in /Users/Dips-Bootcamp/opt/anaconda3/envs/pyvizenv/lib/python3.8/site-packages (from fastai==0.7.0) (3.5.1)
# Requirement already satisfied: pyzmq in /Users/Dips-Bootcamp/opt/anaconda3/envs/pyvizenv/lib/python3.8/site-packages (from fastai==0.7.0) (20.0.0)
# Collecting torch<0.4
#   Downloading torch-0.1.2.post2.tar.gz (128 kB)
#      |████████████████████████████████| 128 kB 12.8 MB/s eta 0:00:01
# Requirement already satisfied: ipython in /Users/Dips-Bootcamp/opt/anaconda3/envs/pyvizenv/lib/python3.8/site-packages (from fastai==0.7.0) (7.21.0)
# Requirement already satisfied: jsonschema in /Users/Dips-Bootcamp/opt/anaconda3/envs/pyvizenv/lib/python3.8/site-packages (from fastai==0.7.0) (3.2.0)
# Collecting torchtext
#   Downloading torchtext-0.10.0-cp38-cp38-macosx_10_9_x86_64.whl (1.6 MB)
#      |████████████████████████████████| 1.6 MB 5.3 MB/s eta 0:00:01
# Requirement already satisfied: pickleshare in /Users/Dips-Bootcamp/opt/anaconda3/envs/pyvizenv/lib/python3.8/site-packages (from fastai==0.7.0) (0.7.5)
# Collecting isoweek
#   Downloading isoweek-1.3.3-py2.py3-none-any.whl (7.1 kB)
# Requirement already satisfied: numpy in /Users/Dips-Bootcamp/opt/anaconda3/envs/pyvizenv/lib/python3.8/site-packages (from fastai==0.7.0) (1.19.5)
# Collecting opencv-python
#   Downloading opencv-python-4.5.3.56.tar.gz (89.2 MB)
#      |████████████████████████████████| 89.2 MB 79 kB/s s eta 0:00:01     |██████████████████              | 50.0 MB 15.7 MB/s eta 0:00:03     |██████████████████████▉         | 63.6 MB 20.1 MB/s eta 0:00:02
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#     Preparing wheel metadata ... done
# Requirement already satisfied: Jinja2 in /Users/Dips-Bootcamp/opt/anaconda3/envs/pyvizenv/lib/python3.8/site-packages (from fastai==0.7.0) (2.11.3)
# Requirement already satisfied: ptyprocess in /Users/Dips-Bootcamp/opt/anaconda3/envs/pyvizenv/lib/python3.8/site-packages (from fastai==0.7.0) (0.7.0)
# Requirement already satisfied: packaging in /Users/Dips-Bootcamp/opt/anaconda3/envs/pyvizenv/lib/python3.8/site-packages (from bleach->fastai==0.7.0) (20.9)
# Requirement already satisfied: six>=1.9.0 in /Users/Dips-Bootcamp/opt/anaconda3/envs/pyvizenv/lib/python3.8/site-packages (from bleach->fastai==0.7.0) (1.15.0)
# Collecting pyarrow>=0.4.0
#   Downloading pyarrow-5.0.0-cp38-cp38-macosx_10_13_x86_64.whl (17.6 MB)
#      |████████████████████████████████| 17.6 MB 10.2 MB/s eta 0:00:01    |██████████▊                     | 5.9 MB 14.4 MB/s eta 0:00:01     |█████████████████████████████   | 15.9 MB 10.2 MB/s eta 0:00:01     |███████████████████████████████▉| 17.5 MB 10.2 MB/s eta 0:00:01
# Requirement already satisfied: appnope in /Users/Dips-Bootcamp/opt/anaconda3/envs/pyvizenv/lib/python3.8/site-packages (from ipykernel->fastai==0.7.0) (0.1.2)
# Requirement already satisfied: jupyter-client in /Users/Dips-Bootcamp/opt/anaconda3/envs/pyvizenv/lib/python3.8/site-packages (from ipykernel->fastai==0.7.0) (6.1.7)
# Requirement already satisfied: setuptools>=18.5 in /Users/Dips-Bootcamp/opt/anaconda3/envs/pyvizenv/lib/python3.8/site-packages (from ipython->fastai==0.7.0) (52.0.0.post20210125)
# Requirement already satisfied: pexpect>4.3 in /Users/Dips-Bootcamp/opt/anaconda3/envs/pyvizenv/lib/python3.8/site-packages (from ipython->fastai==0.7.0) (4.8.0)
# Requirement already satisfied: backcall in /Users/Dips-Bootcamp/opt/anaconda3/envs/pyvizenv/lib/python3.8/site-packages (from ipython->fastai==0.7.0) (0.2.0)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in /Users/Dips-Bootcamp/opt/anaconda3/envs/pyvizenv/lib/python3.8/site-packages (from ipython->fastai==0.7.0) (3.0.17)
# Requirement already satisfied: parso<0.8.0,>=0.7.0 in /Users/Dips-Bootcamp/opt/anaconda3/envs/pyvizenv/lib/python3.8/site-packages (from jedi->fastai==0.7.0) (0.7.0)
# Requirement already satisfied: jupyterlab-widgets>=1.0.0 in /Users/Dips-Bootcamp/opt/anaconda3/envs/pyvizenv/lib/python3.8/site-packages (from ipywidgets->fastai==0.7.0) (1.0.0)
# Requirement already satisfied: nbformat>=4.2.0 in /Users/Dips-Bootcamp/opt/anaconda3/envs/pyvizenv/lib/python3.8/site-packages (from ipywidgets->fastai==0.7.0) (5.1.2)
# Requirement already satisfied: jupyter-core in /Users/Dips-Bootcamp/opt/anaconda3/envs/pyvizenv/lib/python3.8/site-packages (from nbformat>=4.2.0->ipywidgets->fastai==0.7.0) (4.7.1)
# Requirement already satisfied: attrs>=17.4.0 in /Users/Dips-Bootcamp/opt/anaconda3/envs/pyvizenv/lib/python3.8/site-packages (from jsonschema->fastai==0.7.0) (20.3.0)
# Requirement already satisfied: pyrsistent>=0.14.0 in /Users/Dips-Bootcamp/opt/anaconda3/envs/pyvizenv/lib/python3.8/site-packages (from jsonschema->fastai==0.7.0) (0.17.3)
# Requirement already satisfied: notebook>=4.4.1 in /Users/Dips-Bootcamp/opt/anaconda3/envs/pyvizenv/lib/python3.8/site-packages (from widgetsnbextension->fastai==0.7.0) (6.3.0)
# Requirement already satisfied: Send2Trash>=1.5.0 in /Users/Dips-Bootcamp/opt/anaconda3/envs/pyvizenv/lib/python3.8/site-packages (from notebook>=4.4.1->widgetsnbextension->fastai==0.7.0) (1.5.0)
# Requirement already satisfied: nbconvert in /Users/Dips-Bootcamp/opt/anaconda3/envs/pyvizenv/lib/python3.8/site-packages (from notebook>=4.4.1->widgetsnbextension->fastai==0.7.0) (6.0.7)
# Requirement already satisfied: prometheus-client in /Users/Dips-Bootcamp/opt/anaconda3/envs/pyvizenv/lib/python3.8/site-packages (from notebook>=4.4.1->widgetsnbextension->fastai==0.7.0) (0.9.0)
# Requirement already satisfied: terminado>=0.8.3 in /Users/Dips-Bootcamp/opt/anaconda3/envs/pyvizenv/lib/python3.8/site-packages (from notebook>=4.4.1->widgetsnbextension->fastai==0.7.0) (0.9.3)
# Requirement already satisfied: argon2-cffi in /Users/Dips-Bootcamp/opt/anaconda3/envs/pyvizenv/lib/python3.8/site-packages (from notebook>=4.4.1->widgetsnbextension->fastai==0.7.0) (20.1.0)
# Requirement already satisfied: cffi>=1.0.0 in /Users/Dips-Bootcamp/opt/anaconda3/envs/pyvizenv/lib/python3.8/site-packages (from argon2-cffi->notebook>=4.4.1->widgetsnbextension->fastai==0.7.0) (1.14.5)
# Requirement already satisfied: pycparser in /Users/Dips-Bootcamp/opt/anaconda3/envs/pyvizenv/lib/python3.8/site-packages (from cffi>=1.0.0->argon2-cffi->notebook>=4.4.1->widgetsnbextension->fastai==0.7.0) (2.20)
# Requirement already satisfied: qtconsole in /Users/Dips-Bootcamp/opt/anaconda3/envs/pyvizenv/lib/python3.8/site-packages (from jupyter->fastai==0.7.0) (5.0.3)
# Requirement already satisfied: jupyter-console in /Users/Dips-Bootcamp/opt/anaconda3/envs/pyvizenv/lib/python3.8/site-packages (from jupyter->fastai==0.7.0) (6.3.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /Users/Dips-Bootcamp/opt/anaconda3/envs/pyvizenv/lib/python3.8/site-packages (from matplotlib->fastai==0.7.0) (1.3.1)
# Requirement already satisfied: defusedxml in /Users/Dips-Bootcamp/opt/anaconda3/envs/pyvizenv/lib/python3.8/site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension->fastai==0.7.0) (0.7.1)
# Requirement already satisfied: nbclient<0.6.0,>=0.5.0 in /Users/Dips-Bootcamp/opt/anaconda3/envs/pyvizenv/lib/python3.8/site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension->fastai==0.7.0) (0.5.3)
# Requirement already satisfied: mistune<2,>=0.8.1 in /Users/Dips-Bootcamp/opt/anaconda3/envs/pyvizenv/lib/python3.8/site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension->fastai==0.7.0) (0.8.4)
# Requirement already satisfied: jupyterlab-pygments in /Users/Dips-Bootcamp/opt/anaconda3/envs/pyvizenv/lib/python3.8/site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension->fastai==0.7.0) (0.1.2)
# Requirement already satisfied: pandocfilters>=1.4.1 in /Users/Dips-Bootcamp/opt/anaconda3/envs/pyvizenv/lib/python3.8/site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension->fastai==0.7.0) (1.4.3)
# Requirement already satisfied: nest-asyncio in /Users/Dips-Bootcamp/opt/anaconda3/envs/pyvizenv/lib/python3.8/site-packages (from nbclient<0.6.0,>=0.5.0->nbconvert->notebook>=4.4.1->widgetsnbextension->fastai==0.7.0) (1.5.1)
# Requirement already satisfied: async-generator in /Users/Dips-Bootcamp/opt/anaconda3/envs/pyvizenv/lib/python3.8/site-packages (from nbclient<0.6.0,>=0.5.0->nbconvert->notebook>=4.4.1->widgetsnbextension->fastai==0.7.0) (1.10)
# Collecting mizani>=0.7.3
#   Downloading mizani-0.7.3-py3-none-any.whl (63 kB)
#      |████████████████████████████████| 63 kB 4.0 MB/s  eta 0:00:01
# Requirement already satisfied: patsy>=0.5.1 in /Users/Dips-Bootcamp/opt/anaconda3/envs/pyvizenv/lib/python3.8/site-packages (from plotnine->fastai==0.7.0) (0.5.1)
# Collecting statsmodels>=0.12.1
#   Using cached statsmodels-0.12.2.tar.gz (17.5 MB)
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#     Preparing wheel metadata ... done
# Collecting descartes>=1.1.0
#   Downloading descartes-1.1.0-py3-none-any.whl (5.8 kB)
# Collecting palettable
#   Downloading palettable-3.3.0-py2.py3-none-any.whl (111 kB)
#      |████████████████████████████████| 111 kB 18.5 MB/s eta 0:00:01
# Requirement already satisfied: qtpy in /Users/Dips-Bootcamp/opt/anaconda3/envs/pyvizenv/lib/python3.8/site-packages (from qtconsole->jupyter->fastai==0.7.0) (1.9.0)
# Requirement already satisfied: scikit-learn>=0.23.0 in /Users/Dips-Bootcamp/opt/anaconda3/envs/pyvizenv/lib/python3.8/site-packages (from sklearn-pandas->fastai==0.7.0) (0.24.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /Users/Dips-Bootcamp/opt/anaconda3/envs/pyvizenv/lib/python3.8/site-packages (from scikit-learn>=0.23.0->sklearn-pandas->fastai==0.7.0) (2.1.0)
# Requirement already satisfied: joblib>=0.11 in /Users/Dips-Bootcamp/opt/anaconda3/envs/pyvizenv/lib/python3.8/site-packages (from scikit-learn>=0.23.0->sklearn-pandas->fastai==0.7.0) (1.0.1)
# Requirement already satisfied: requests in /Users/Dips-Bootcamp/opt/anaconda3/envs/pyvizenv/lib/python3.8/site-packages (from torchtext->fastai==0.7.0) (2.25.1)
# Collecting torchtext
#   Downloading torchtext-0.9.1-cp38-cp38-macosx_10_9_x86_64.whl (1.6 MB)
#      |████████████████████████████████| 1.6 MB 3.7 MB/s eta 0:00:01
#   Downloading torchtext-0.9.0-cp38-cp38-macosx_10_9_x86_64.whl (1.6 MB)
#      |████████████████████████████████| 1.6 MB 23.9 MB/s eta 0:00:01
#   Downloading torchtext-0.8.1-cp38-cp38-macosx_10_9_x86_64.whl (1.5 MB)
#      |████████████████████████████████| 1.5 MB 17.8 MB/s eta 0:00:01
#   Downloading torchtext-0.8.0-cp38-cp38-macosx_10_9_x86_64.whl (1.5 MB)
#      |████████████████████████████████| 1.5 MB 25.0 MB/s eta 0:00:01
# Requirement already satisfied: chardet<5,>=3.0.2 in /Users/Dips-Bootcamp/opt/anaconda3/envs/pyvizenv/lib/python3.8/site-packages (from requests->torchtext->fastai==0.7.0) (4.0.0)
# Requirement already satisfied: idna<3,>=2.5 in /Users/Dips-Bootcamp/opt/anaconda3/envs/pyvizenv/lib/python3.8/site-packages (from requests->torchtext->fastai==0.7.0) (2.10)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /Users/Dips-Bootcamp/opt/anaconda3/envs/pyvizenv/lib/python3.8/site-packages (from requests->torchtext->fastai==0.7.0) (1.26.4)
# Collecting torchvision
#   Downloading torchvision-0.9.1-cp38-cp38-macosx_10_9_x86_64.whl (13.2 MB)
#      |████████████████████████████████| 13.2 MB 21.6 MB/s eta 0:00:01     |██████████████████████████████  | 12.3 MB 21.6 MB/s eta 0:00:01
#   Downloading torchvision-0.9.0-cp38-cp38-macosx_10_9_x86_64.whl (13.2 MB)
#      |████████████████████████████████| 13.2 MB 18.9 MB/s eta 0:00:01
#   Downloading torchvision-0.8.2-cp38-cp38-macosx_10_9_x86_64.whl (1.0 MB)
#      |████████████████████████████████| 1.0 MB 28.0 MB/s eta 0:00:01
#   Downloading torchvision-0.8.1-cp38-cp38-macosx_10_9_x86_64.whl (1.0 MB)
#      |████████████████████████████████| 1.0 MB 39.1 MB/s eta 0:00:01
#   Downloading torchvision-0.8.0-cp38-cp38-macosx_10_9_x86_64.whl (1.0 MB)
#      |████████████████████████████████| 1.0 MB 26.2 MB/s eta 0:00:01
#   Downloading torchvision-0.7.0-cp38-cp38-macosx_10_9_x86_64.whl (387 kB)
#      |████████████████████████████████| 387 kB 48.5 MB/s eta 0:00:01
#   Downloading torchvision-0.6.1-cp38-cp38-macosx_10_9_x86_64.whl (436 kB)
#      |████████████████████████████████| 436 kB 32.8 MB/s eta 0:00:01
#   Downloading torchvision-0.6.0-cp38-cp38-macosx_10_9_x86_64.whl (436 kB)
#      |████████████████████████████████| 436 kB 23.5 MB/s eta 0:00:01
#   Downloading torchvision-0.5.0-cp38-cp38-macosx_10_9_x86_64.whl (438 kB)
#      |████████████████████████████████| 438 kB 39.0 MB/s eta 0:00:01
#   Downloading torchvision-0.2.2.post3-py2.py3-none-any.whl (64 kB)
#      |████████████████████████████████| 64 kB 8.4 MB/s  eta 0:00:01
# WARNING: The candidate selected for download or install is a yanked version: 'torch' candidate (version 0.1.2.post2 at https://files.pythonhosted.org/packages/f8/02/880b468bd382dc79896eaecbeb8ce95e9c4b99a24902874a2cef0b562cea/torch-0.1.2.post2.tar.gz#sha256=a43e37f8f927c5b18f80cd163daaf6a1920edafcab5102e02e3e14bb97d9c874 (from https://pypi.org/simple/torch/))
# Reason for being yanked: 0.1.2 is past it's support date and confuses users on unsupported platforms
# Building wheels for collected packages: torch, bcolz, feather-format, opencv-python, statsmodels
#   Building wheel for torch (setup.py) ... error
#   ERROR: Command errored out with exit status 1:
#    command: /Users/Dips-Bootcamp/opt/anaconda3/envs/pyvizenv/bin/python -u -c 'import sys, setuptools, tokenize; sys.argv[0] = '"'"'/private/var/folders/6z/v067s0695rj7g096206l10540000gp/T/pip-install-iiakkh9q/torch_c46243b5e3704e1aa83494e4662ef404/setup.py'"'"'; __file__='"'"'/private/var/folders/6z/v067s0695rj7g096206l10540000gp/T/pip-install-iiakkh9q/torch_c46243b5e3704e1aa83494e4662ef404/setup.py'"'"';f=getattr(tokenize, '"'"'open'"'"', open)(__file__);code=f.read().replace('"'"'\r\n'"'"', '"'"'\n'"'"');f.close();exec(compile(code, __file__, '"'"'exec'"'"'))' bdist_wheel -d /private/var/folders/6z/v067s0695rj7g096206l10540000gp/T/pip-wheel-k06u83at
#        cwd: /private/var/folders/6z/v067s0695rj7g096206l10540000gp/T/pip-install-iiakkh9q/torch_c46243b5e3704e1aa83494e4662ef404/
#   Complete output (30 lines):
#   running bdist_wheel
#   running build
#   running build_deps
#   Traceback (most recent call last):
#     File "<string>", line 1, in <module>
#     File "/private/var/folders/6z/v067s0695rj7g096206l10540000gp/T/pip-install-iiakkh9q/torch_c46243b5e3704e1aa83494e4662ef404/setup.py", line 225, in <module>
#       setup(name="torch", version="0.1.2.post2",
#     File "/Users/Dips-Bootcamp/opt/anaconda3/envs/pyvizenv/lib/python3.8/site-packages/setuptools/__init__.py", line 153, in setup
#       return distutils.core.setup(**attrs)
#     File "/Users/Dips-Bootcamp/opt/anaconda3/envs/pyvizenv/lib/python3.8/distutils/core.py", line 148, in setup
#       dist.run_commands()
#     File "/Users/Dips-Bootcamp/opt/anaconda3/envs/pyvizenv/lib/python3.8/distutils/dist.py", line 966, in run_commands
#       self.run_command(cmd)
#     File "/Users/Dips-Bootcamp/opt/anaconda3/envs/pyvizenv/lib/python3.8/distutils/dist.py", line 985, in run_command
#       cmd_obj.run()
#     File "/Users/Dips-Bootcamp/opt/anaconda3/envs/pyvizenv/lib/python3.8/site-packages/wheel/bdist_wheel.py", line 299, in run
#       self.run_command('build')
#     File "/Users/Dips-Bootcamp/opt/anaconda3/envs/pyvizenv/lib/python3.8/distutils/cmd.py", line 313, in run_command
#       self.distribution.run_command(command)
#     File "/Users/Dips-Bootcamp/opt/anaconda3/envs/pyvizenv/lib/python3.8/distutils/dist.py", line 985, in run_command
#       cmd_obj.run()
#     File "/Users/Dips-Bootcamp/opt/anaconda3/envs/pyvizenv/lib/python3.8/distutils/command/build.py", line 135, in run
#       self.run_command(cmd_name)
#     File "/Users/Dips-Bootcamp/opt/anaconda3/envs/pyvizenv/lib/python3.8/distutils/cmd.py", line 313, in run_command
#       self.distribution.run_command(command)
#     File "/Users/Dips-Bootcamp/opt/anaconda3/envs/pyvizenv/lib/python3.8/distutils/dist.py", line 985, in run_command
#       cmd_obj.run()
#     File "/private/var/folders/6z/v067s0695rj7g096206l10540000gp/T/pip-install-iiakkh9q/torch_c46243b5e3704e1aa83494e4662ef404/setup.py", line 51, in run
#       from tools.nnwrap import generate_wrappers as generate_nn_wrappers
#   ModuleNotFoundError: No module named 'tools.nnwrap'
#   ----------------------------------------
#   ERROR: Failed building wheel for torch
#   Running setup.py clean for torch
#   ERROR: Command errored out with exit status 1:
#    command: /Users/Dips-Bootcamp/opt/anaconda3/envs/pyvizenv/bin/python -u -c 'import sys, setuptools, tokenize; sys.argv[0] = '"'"'/private/var/folders/6z/v067s0695rj7g096206l10540000gp/T/pip-install-iiakkh9q/torch_c46243b5e3704e1aa83494e4662ef404/setup.py'"'"'; __file__='"'"'/private/var/folders/6z/v067s0695rj7g096206l10540000gp/T/pip-install-iiakkh9q/torch_c46243b5e3704e1aa83494e4662ef404/setup.py'"'"';f=getattr(tokenize, '"'"'open'"'"', open)(__file__);code=f.read().replace('"'"'\r\n'"'"', '"'"'\n'"'"');f.close();exec(compile(code, __file__, '"'"'exec'"'"'))' clean --all
#        cwd: /private/var/folders/6z/v067s0695rj7g096206l10540000gp/T/pip-install-iiakkh9q/torch_c46243b5e3704e1aa83494e4662ef404
#   Complete output (2 lines):
#   running clean
#   error: [Errno 2] No such file or directory: '.gitignore'
#   ----------------------------------------
#   ERROR: Failed cleaning build dir for torch
#   Building wheel for bcolz (setup.py) ... error
#   ERROR: Command errored out with exit status 1:
#    command: /Users/Dips-Bootcamp/opt/anaconda3/envs/pyvizenv/bin/python -u -c 'import sys, setuptools, tokenize; sys.argv[0] = '"'"'/private/var/folders/6z/v067s0695rj7g096206l10540000gp/T/pip-install-iiakkh9q/bcolz_5cf49a2d92b149b8811a4e6ef2d8a5d1/setup.py'"'"'; __file__='"'"'/private/var/folders/6z/v067s0695rj7g096206l10540000gp/T/pip-install-iiakkh9q/bcolz_5cf49a2d92b149b8811a4e6ef2d8a5d1/setup.py'"'"';f=getattr(tokenize, '"'"'open'"'"', open)(__file__);code=f.read().replace('"'"'\r\n'"'"', '"'"'\n'"'"');f.close();exec(compile(code, __file__, '"'"'exec'"'"'))' bdist_wheel -d /private/var/folders/6z/v067s0695rj7g096206l10540000gp/T/pip-wheel-la_qa8_6
#        cwd: /private/var/folders/6z/v067s0695rj7g096206l10540000gp/T/pip-install-iiakkh9q/bcolz_5cf49a2d92b149b8811a4e6ef2d8a5d1/
#   Complete output (415 lines):
#   SSE2 detected
#   running bdist_wheel
#   running build
#   running build_py
#   creating build
#   creating build/lib.macosx-10.9-x86_64-3.8
#   creating build/lib.macosx-10.9-x86_64-3.8/bcolz
#   copying bcolz/py2help_tests.py -> build/lib.macosx-10.9-x86_64-3.8/bcolz
#   copying bcolz/version.py -> build/lib.macosx-10.9-x86_64-3.8/bcolz
#   copying bcolz/toplevel.py -> build/lib.macosx-10.9-x86_64-3.8/bcolz
#   copying bcolz/ctable.py -> build/lib.macosx-10.9-x86_64-3.8/bcolz
#   copying bcolz/__init__.py -> build/lib.macosx-10.9-x86_64-3.8/bcolz
#   copying bcolz/utils.py -> build/lib.macosx-10.9-x86_64-3.8/bcolz
#   copying bcolz/chunked_eval.py -> build/lib.macosx-10.9-x86_64-3.8/bcolz
#   copying bcolz/defaults.py -> build/lib.macosx-10.9-x86_64-3.8/bcolz
#   copying bcolz/attrs.py -> build/lib.macosx-10.9-x86_64-3.8/bcolz
#   copying bcolz/py2help.py -> build/lib.macosx-10.9-x86_64-3.8/bcolz
#   copying bcolz/arrayprint.py -> build/lib.macosx-10.9-x86_64-3.8/bcolz
#   creating build/lib.macosx-10.9-x86_64-3.8/bcolz/tests
#   copying bcolz/tests/test_ndcarray.py -> build/lib.macosx-10.9-x86_64-3.8/bcolz/tests
#   copying bcolz/tests/test_carray_objects.py -> build/lib.macosx-10.9-x86_64-3.8/bcolz/tests
#   copying bcolz/tests/test_attrs.py -> build/lib.macosx-10.9-x86_64-3.8/bcolz/tests
#   copying bcolz/tests/__init__.py -> build/lib.macosx-10.9-x86_64-3.8/bcolz/tests
#   copying bcolz/tests/all.py -> build/lib.macosx-10.9-x86_64-3.8/bcolz/tests
#   copying bcolz/tests/common.py -> build/lib.macosx-10.9-x86_64-3.8/bcolz/tests
#   copying bcolz/tests/test_queries.py -> build/lib.macosx-10.9-x86_64-3.8/bcolz/tests
#   copying bcolz/tests/test_ctable.py -> build/lib.macosx-10.9-x86_64-3.8/bcolz/tests
#   copying bcolz/tests/test_carray.py -> build/lib.macosx-10.9-x86_64-3.8/bcolz/tests
#   copying bcolz/carray_ext.pxd -> build/lib.macosx-10.9-x86_64-3.8/bcolz
#   running build_ext
#   skipping 'bcolz/carray_ext.c' Cython extension (up-to-date)
#   building 'bcolz.carray_ext' extension
#   creating build/temp.macosx-10.9-x86_64-3.8
#   creating build/temp.macosx-10.9-x86_64-3.8/bcolz
#   creating build/temp.macosx-10.9-x86_64-3.8/c-blosc
#   creating build/temp.macosx-10.9-x86_64-3.8/c-blosc/blosc
#   creating build/temp.macosx-10.9-x86_64-3.8/c-blosc/internal-complibs
#   creating build/temp.macosx-10.9-x86_64-3.8/c-blosc/internal-complibs/lz4-1.8.1.2
#   creating build/temp.macosx-10.9-x86_64-3.8/c-blosc/internal-complibs/snappy-1.1.1
#   creating build/temp.macosx-10.9-x86_64-3.8/c-blosc/internal-complibs/zlib-1.2.8
#   creating build/temp.macosx-10.9-x86_64-3.8/c-blosc/internal-complibs/zstd-1.3.4
#   creating build/temp.macosx-10.9-x86_64-3.8/c-blosc/internal-complibs/zstd-1.3.4/compress
#   creating build/temp.macosx-10.9-x86_64-3.8/c-blosc/internal-complibs/zstd-1.3.4/dictBuilder
#   creating build/temp.macosx-10.9-x86_64-3.8/c-blosc/internal-complibs/zstd-1.3.4/decompress
#   creating build/temp.macosx-10.9-x86_64-3.8/c-blosc/internal-complibs/zstd-1.3.4/legacy
#   creating build/temp.macosx-10.9-x86_64-3.8/c-blosc/internal-complibs/zstd-1.3.4/common
#   creating build/temp.macosx-10.9-x86_64-3.8/c-blosc/internal-complibs/zstd-1.3.4/deprecated
#   gcc -Wno-unused-result -Wsign-compare -Wunreachable-code -DNDEBUG -g -fwrapv -O3 -Wall -Wstrict-prototypes -I/Users/Dips-Bootcamp/opt/anaconda3/envs/pyvizenv/include -arch x86_64 -I/Users/Dips-Bootcamp/opt/anaconda3/envs/pyvizenv/include -arch x86_64 -DHAVE_LZ4=1 -DHAVE_SNAPPY=1 -DHAVE_ZLIB=1 -DHAVE_ZSTD=1 -Ibcolz -Ic-blosc/blosc -Ic-blosc/internal-complibs/zstd-1.3.4 -Ic-blosc/internal-complibs/lz4-1.8.1.2 -Ic-blosc/internal-complibs/snappy-1.1.1 -Ic-blosc/internal-complibs/zlib-1.2.8 -Ic-blosc/internal-complibs/zstd-1.3.4/compress -Ic-blosc/internal-complibs/zstd-1.3.4/dictBuilder -Ic-blosc/internal-complibs/zstd-1.3.4/decompress -Ic-blosc/internal-complibs/zstd-1.3.4/legacy -Ic-blosc/internal-complibs/zstd-1.3.4/common -Ic-blosc/internal-complibs/zstd-1.3.4/dll -Ic-blosc/internal-complibs/zstd-1.3.4/deprecated -I/Users/Dips-Bootcamp/opt/anaconda3/envs/pyvizenv/lib/python3.8/site-packages/numpy/core/include -I/Users/Dips-Bootcamp/opt/anaconda3/envs/pyvizenv/include/python3.8 -c bcolz/carray_ext.c -o build/temp.macosx-10.9-x86_64-3.8/bcolz/carray_ext.o -DSHUFFLE_SSE2_ENABLED -msse2
#   In file included from bcolz/carray_ext.c:525:
#   In file included from /Users/Dips-Bootcamp/opt/anaconda3/envs/pyvizenv/lib/python3.8/site-packages/numpy/core/include/numpy/arrayobject.h:4:
#   In file included from /Users/Dips-Bootcamp/opt/anaconda3/envs/pyvizenv/lib/python3.8/site-packages/numpy/core/include/numpy/ndarrayobject.h:12:
#   In file included from /Users/Dips-Bootcamp/opt/anaconda3/envs/pyvizenv/lib/python3.8/site-packages/numpy/core/include/numpy/ndarraytypes.h:1822:
#   /Users/Dips-Bootcamp/opt/anaconda3/envs/pyvizenv/lib/python3.8/site-packages/numpy/core/include/numpy/npy_1_7_deprecated_api.h:17:2: warning: "Using deprecated NumPy API, disable it with "          "#define NPY_NO_DEPRECATED_API NPY_1_7_API_VERSION" [-W#warnings]
#   #warning "Using deprecated NumPy API, disable it with " \
#    ^
#   bcolz/carray_ext.c:45964:40: warning: 'tp_print' is deprecated [-Wdeprecated-declarations]
#     __pyx_type_5bcolz_10carray_ext_chunk.tp_print = 0;
#                                          ^
#   /Users/Dips-Bootcamp/opt/anaconda3/envs/pyvizenv/include/python3.8/cpython/object.h:260:5: note: 'tp_print' has been explicitly marked deprecated here
#       Py_DEPRECATED(3.8) int (*tp_print)(PyObject *, FILE *, int);
#       ^
#   /Users/Dips-Bootcamp/opt/anaconda3/envs/pyvizenv/include/python3.8/pyport.h:515:54: note: expanded from macro 'Py_DEPRECATED'
#   #define Py_DEPRECATED(VERSION_UNUSED) __attribute__((__deprecated__))
#                                                        ^
#   bcolz/carray_ext.c:46014:41: warning: 'tp_print' is deprecated [-Wdeprecated-declarations]
#     __pyx_type_5bcolz_10carray_ext_chunks.tp_print = 0;
#                                           ^
#   /Users/Dips-Bootcamp/opt/anaconda3/envs/pyvizenv/include/python3.8/cpython/object.h:260:5: note: 'tp_print' has been explicitly marked deprecated here
#       Py_DEPRECATED(3.8) int (*tp_print)(PyObject *, FILE *, int);
#       ^
#   /Users/Dips-Bootcamp/opt/anaconda3/envs/pyvizenv/include/python3.8/pyport.h:515:54: note: expanded from macro 'Py_DEPRECATED'
#   #define Py_DEPRECATED(VERSION_UNUSED) __attribute__((__deprecated__))
#                                                        ^
#   bcolz/carray_ext.c:46026:41: warning: 'tp_print' is deprecated [-Wdeprecated-declarations]
#     __pyx_type_5bcolz_10carray_ext_carray.tp_print = 0;
#                                           ^
#   /Users/Dips-Bootcamp/opt/anaconda3/envs/pyvizenv/include/python3.8/cpython/object.h:260:5: note: 'tp_print' has been explicitly marked deprecated here
#       Py_DEPRECATED(3.8) int (*tp_print)(PyObject *, FILE *, int);
#       ^
#   /Users/Dips-Bootcamp/opt/anaconda3/envs/pyvizenv/include/python3.8/pyport.h:515:54: note: expanded from macro 'Py_DEPRECATED'
#   #define Py_DEPRECATED(VERSION_UNUSED) __attribute__((__deprecated__))
#                                                        ^
#   4 warnings generated.
#   gcc -Wno-unused-result -Wsign-compare -Wunreachable-code -DNDEBUG -g -fwrapv -O3 -Wall -Wstrict-prototypes -I/Users/Dips-Bootcamp/opt/anaconda3/envs/pyvizenv/include -arch x86_64 -I/Users/Dips-Bootcamp/opt/anaconda3/envs/pyvizenv/include -arch x86_64 -DHAVE_LZ4=1 -DHAVE_SNAPPY=1 -DHAVE_ZLIB=1 -DHAVE_ZSTD=1 -Ibcolz -Ic-blosc/blosc -Ic-blosc/internal-complibs/zstd-1.3.4 -Ic-blosc/internal-complibs/lz4-1.8.1.2 -Ic-blosc/internal-complibs/snappy-1.1.1 -Ic-blosc/internal-complibs/zlib-1.2.8 -Ic-blosc/internal-complibs/zstd-1.3.4/compress -Ic-blosc/internal-complibs/zstd-1.3.4/dictBuilder -Ic-blosc/internal-complibs/zstd-1.3.4/decompress -Ic-blosc/internal-complibs/zstd-1.3.4/legacy -Ic-blosc/internal-complibs/zstd-1.3.4/common -Ic-blosc/internal-complibs/zstd-1.3.4/dll -Ic-blosc/internal-complibs/zstd-1.3.4/deprecated -I/Users/Dips-Bootcamp/opt/anaconda3/envs/pyvizenv/lib/python3.8/site-packages/numpy/core/include -I/Users/Dips-Bootcamp/opt/anaconda3/envs/pyvizenv/include/python3.8 -c c-blosc/blosc/blosc.c -o build/temp.macosx-10.9-x86_64-3.8/c-blosc/blosc/blosc.o -DSHUFFLE_SSE2_ENABLED -msse2
#   c-blosc/blosc/blosc.c:435:12: warning: 'LZ4_decompress_fast' is deprecated: This function is deprecated and unsafe. Consider using LZ4_decompress_safe() instead [-Wdeprecated-declarations]
#     cbytes = LZ4_decompress_fast(input, output, (int)maxout);
#              ^
#   /Users/Dips-Bootcamp/opt/anaconda3/envs/pyvizenv/include/lz4.h:753:1: note: 'LZ4_decompress_fast' has been explicitly marked deprecated here
#   LZ4_DEPRECATED("This function is deprecated and unsafe. Consider using LZ4_decompress_safe() instead")
#   ^
#   /Users/Dips-Bootcamp/opt/anaconda3/envs/pyvizenv/include/lz4.h:687:52: note: expanded from macro 'LZ4_DEPRECATED'
#   #    define LZ4_DEPRECATED(message) __attribute__((deprecated(message)))
#                                                      ^
#   c-blosc/blosc/blosc.c:874:7: warning: unused variable 'rc' [-Wunused-variable]
#     int rc;
#         ^
#   c-blosc/blosc/blosc.c:1656:7: warning: unused variable 'rc' [-Wunused-variable]
#     int rc;
#         ^
#   c-blosc/blosc/blosc.c:2136:7: warning: unused variable 'rc' [-Wunused-variable]
#     int rc;
#         ^
#   4 warnings generated.
#   gcc -Wno-unused-result -Wsign-compare -Wunreachable-code -DNDEBUG -g -fwrapv -O3 -Wall -Wstrict-prototypes -I/Users/Dips-Bootcamp/opt/anaconda3/envs/pyvizenv/include -arch x86_64 -I/Users/Dips-Bootcamp/opt/anaconda3/envs/pyvizenv/include -arch x86_64 -DHAVE_LZ4=1 -DHAVE_SNAPPY=1 -DHAVE_ZLIB=1 -DHAVE_ZSTD=1 -Ibcolz -Ic-blosc/blosc -Ic-blosc/internal-complibs/zstd-1.3.4 -Ic-blosc/internal-complibs/lz4-1.8.1.2 -Ic-blosc/internal-complibs/snappy-1.1.1 -Ic-blosc/internal-complibs/zlib-1.2.8 -Ic-blosc/internal-complibs/zstd-1.3.4/compress -Ic-blosc/internal-complibs/zstd-1.3.4/dictBuilder -Ic-blosc/internal-complibs/zstd-1.3.4/decompress -Ic-blosc/internal-complibs/zstd-1.3.4/legacy -Ic-blosc/internal-complibs/zstd-1.3.4/common -Ic-blosc/internal-complibs/zstd-1.3.4/dll -Ic-blosc/internal-complibs/zstd-1.3.4/deprecated -I/Users/Dips-Bootcamp/opt/anaconda3/envs/pyvizenv/lib/python3.8/site-packages/numpy/core/include -I/Users/Dips-Bootcamp/opt/anaconda3/envs/pyvizenv/include/python3.8 -c c-blosc/blosc/bitshuffle-generic.c -o build/temp.macosx-10.9-x86_64-3.8/c-blosc/blosc/bitshuffle-generic.o -DSHUFFLE_SSE2_ENABLED -msse2
#   gcc -Wno-unused-result -Wsign-compare -Wunreachable-code -DNDEBUG -g -fwrapv -O3 -Wall -Wstrict-prototypes -I/Users/Dips-Bootcamp/opt/anaconda3/envs/pyvizenv/include -arch x86_64 -I/Users/Dips-Bootcamp/opt/anaconda3/envs/pyvizenv/include -arch x86_64 -DHAVE_LZ4=1 -DHAVE_SNAPPY=1 -DHAVE_ZLIB=1 -DHAVE_ZSTD=1 -Ibcolz -Ic-blosc/blosc -Ic-blosc/internal-complibs/zstd-1.3.4 -Ic-blosc/internal-complibs/lz4-1.8.1.2 -Ic-blosc/internal-complibs/snappy-1.1.1 -Ic-blosc/internal-complibs/zlib-1.2.8 -Ic-blosc/internal-complibs/zstd-1.3.4/compress -Ic-blosc/internal-complibs/zstd-1.3.4/dictBuilder -Ic-blosc/internal-complibs/zstd-1.3.4/decompress -Ic-blosc/internal-complibs/zstd-1.3.4/legacy -Ic-blosc/internal-complibs/zstd-1.3.4/common -Ic-blosc/internal-complibs/zstd-1.3.4/dll -Ic-blosc/internal-complibs/zstd-1.3.4/deprecated -I/Users/Dips-Bootcamp/opt/anaconda3/envs/pyvizenv/lib/python3.8/site-packages/numpy/core/include -I/Users/Dips-Bootcamp/opt/anaconda3/envs/pyvizenv/include/python3.8 -c c-blosc/blosc/shuffle.c -o build/temp.macosx-10.9-x86_64-3.8/c-blosc/blosc/shuffle.o -DSHUFFLE_SSE2_ENABLED -msse2
#   In file included from c-blosc/blosc/shuffle.c:11:
#   c-blosc/blosc/shuffle-generic.h:32:13: warning: unused function 'shuffle_generic_inline' [-Wunused-function]
#   static void shuffle_generic_inline(const size_t type_size,
#               ^
#   c-blosc/blosc/shuffle-generic.h:61:13: warning: unused function 'unshuffle_generic_inline' [-Wunused-function]
#   static void unshuffle_generic_inline(const size_t type_size,
#               ^
#   2 warnings generated.
#   gcc -Wno-unused-result -Wsign-compare -Wunreachable-code -DNDEBUG -g -fwrapv -O3 -Wall -Wstrict-prototypes -I/Users/Dips-Bootcamp/opt/anaconda3/envs/pyvizenv/include -arch x86_64 -I/Users/Dips-Bootcamp/opt/anaconda3/envs/pyvizenv/include -arch x86_64 -DHAVE_LZ4=1 -DHAVE_SNAPPY=1 -DHAVE_ZLIB=1 -DHAVE_ZSTD=1 -Ibcolz -Ic-blosc/blosc -Ic-blosc/internal-complibs/zstd-1.3.4 -Ic-blosc/internal-complibs/lz4-1.8.1.2 -Ic-blosc/internal-complibs/snappy-1.1.1 -Ic-blosc/internal-complibs/zlib-1.2.8 -Ic-blosc/internal-complibs/zstd-1.3.4/compress -Ic-blosc/internal-complibs/zstd-1.3.4/dictBuilder -Ic-blosc/internal-complibs/zstd-1.3.4/decompress -Ic-blosc/internal-complibs/zstd-1.3.4/legacy -Ic-blosc/internal-complibs/zstd-1.3.4/common -Ic-blosc/internal-complibs/zstd-1.3.4/dll -Ic-blosc/internal-complibs/zstd-1.3.4/deprecated -I/Users/Dips-Bootcamp/opt/anaconda3/envs/pyvizenv/lib/python3.8/site-packages/numpy/core/include -I/Users/Dips-Bootcamp/opt/anaconda3/envs/pyvizenv/include/python3.8 -c c-blosc/blosc/fastcopy.c -o build/temp.macosx-10.9-x86_64-3.8/c-blosc/blosc/fastcopy.o -DSHUFFLE_SSE2_ENABLED -msse2
#   c-blosc/blosc/fastcopy.c:246:30: warning: unused function 'chunk_memcpy_16' [-Wunused-function]
#   static inline unsigned char *chunk_memcpy_16(unsigned char *out, const unsigned char *from, unsigned len) {
#                                ^
#   c-blosc/blosc/fastcopy.c:270:30: warning: unused function 'chunk_memcpy_32' [-Wunused-function]
#   static inline unsigned char *chunk_memcpy_32(unsigned char *out, const unsigned char *from, unsigned len) {
#                                ^
#   c-blosc/blosc/fastcopy.c:294:30: warning: unused function 'chunk_memcpy_32_unrolled' [-Wunused-function]
#   static inline unsigned char *chunk_memcpy_32_unrolled(unsigned char *out, const unsigned char *from, unsigned len) {
#                                ^
#   c-blosc/blosc/fastcopy.c:402:30: warning: unused function 'chunk_memcpy_aligned' [-Wunused-function]
#   static inline unsigned char *chunk_memcpy_aligned(unsigned char *out, const unsigned char *from, unsigned len) {
#                                ^
#   4 warnings generated.
#   gcc -Wno-unused-result -Wsign-compare -Wunreachable-code -DNDEBUG -g -fwrapv -O3 -Wall -Wstrict-prototypes -I/Users/Dips-Bootcamp/opt/anaconda3/envs/pyvizenv/include -arch x86_64 -I/Users/Dips-Bootcamp/opt/anaconda3/envs/pyvizenv/include -arch x86_64 -DHAVE_LZ4=1 -DHAVE_SNAPPY=1 -DHAVE_ZLIB=1 -DHAVE_ZSTD=1 -Ibcolz -Ic-blosc/blosc -Ic-blosc/internal-complibs/zstd-1.3.4 -Ic-blosc/internal-complibs/lz4-1.8.1.2 -Ic-blosc/internal-complibs/snappy-1.1.1 -Ic-blosc/internal-complibs/zlib-1.2.8 -Ic-blosc/internal-complibs/zstd-1.3.4/compress -Ic-blosc/internal-complibs/zstd-1.3.4/dictBuilder -Ic-blosc/internal-complibs/zstd-1.3.4/decompress -Ic-blosc/internal-complibs/zstd-1.3.4/legacy -Ic-blosc/internal-complibs/zstd-1.3.4/common -Ic-blosc/internal-complibs/zstd-1.3.4/dll -Ic-blosc/internal-complibs/zstd-1.3.4/deprecated -I/Users/Dips-Bootcamp/opt/anaconda3/envs/pyvizenv/lib/python3.8/site-packages/numpy/core/include -I/Users/Dips-Bootcamp/opt/anaconda3/envs/pyvizenv/include/python3.8 -c c-blosc/blosc/blosclz.c -o build/temp.macosx-10.9-x86_64-3.8/c-blosc/blosc/blosclz.o -DSHUFFLE_SSE2_ENABLED -msse2
#   c-blosc/blosc/blosclz.c:82:24: warning: unused function 'get_run' [-Wunused-function]
#   static inline uint8_t *get_run(uint8_t *ip, const uint8_t *ip_bound, const uint8_t *ref) {
#                          ^
#   1 warning generated.
#   gcc -Wno-unused-result -Wsign-compare -Wunreachable-code -DNDEBUG -g -fwrapv -O3 -Wall -Wstrict-prototypes -I/Users/Dips-Bootcamp/opt/anaconda3/envs/pyvizenv/include -arch x86_64 -I/Users/Dips-Bootcamp/opt/anaconda3/envs/pyvizenv/include -arch x86_64 -DHAVE_LZ4=1 -DHAVE_SNAPPY=1 -DHAVE_ZLIB=1 -DHAVE_ZSTD=1 -Ibcolz -Ic-blosc/blosc -Ic-blosc/internal-complibs/zstd-1.3.4 -Ic-blosc/internal-complibs/lz4-1.8.1.2 -Ic-blosc/internal-complibs/snappy-1.1.1 -Ic-blosc/internal-complibs/zlib-1.2.8 -Ic-blosc/internal-complibs/zstd-1.3.4/compress -Ic-blosc/internal-complibs/zstd-1.3.4/dictBuilder -Ic-blosc/internal-complibs/zstd-1.3.4/decompress -Ic-blosc/internal-complibs/zstd-1.3.4/legacy -Ic-blosc/internal-complibs/zstd-1.3.4/common -Ic-blosc/internal-complibs/zstd-1.3.4/dll -Ic-blosc/internal-complibs/zstd-1.3.4/deprecated -I/Users/Dips-Bootcamp/opt/anaconda3/envs/pyvizenv/lib/python3.8/site-packages/numpy/core/include -I/Users/Dips-Bootcamp/opt/anaconda3/envs/pyvizenv/include/python3.8 -c c-blosc/blosc/shuffle-generic.c -o build/temp.macosx-10.9-x86_64-3.8/c-blosc/blosc/shuffle-generic.o -DSHUFFLE_SSE2_ENABLED -msse2
#   gcc -Wno-unused-result -Wsign-compare -Wunreachable-code -DNDEBUG -g -fwrapv -O3 -Wall -Wstrict-prototypes -I/Users/Dips-Bootcamp/opt/anaconda3/envs/pyvizenv/include -arch x86_64 -I/Users/Dips-Bootcamp/opt/anaconda3/envs/pyvizenv/include -arch x86_64 -DHAVE_LZ4=1 -DHAVE_SNAPPY=1 -DHAVE_ZLIB=1 -DHAVE_ZSTD=1 -Ibcolz -Ic-blosc/blosc -Ic-blosc/internal-complibs/zstd-1.3.4 -Ic-blosc/internal-complibs/lz4-1.8.1.2 -Ic-blosc/internal-complibs/snappy-1.1.1 -Ic-blosc/internal-complibs/zlib-1.2.8 -Ic-blosc/internal-complibs/zstd-1.3.4/compress -Ic-blosc/internal-complibs/zstd-1.3.4/dictBuilder -Ic-blosc/internal-complibs/zstd-1.3.4/decompress -Ic-blosc/internal-complibs/zstd-1.3.4/legacy -Ic-blosc/internal-complibs/zstd-1.3.4/common -Ic-blosc/internal-complibs/zstd-1.3.4/dll -Ic-blosc/internal-complibs/zstd-1.3.4/deprecated -I/Users/Dips-Bootcamp/opt/anaconda3/envs/pyvizenv/lib/python3.8/site-packages/numpy/core/include -I/Users/Dips-Bootcamp/opt/anaconda3/envs/pyvizenv/include/python3.8 -c c-blosc/internal-complibs/lz4-1.8.1.2/lz4hc.c -o build/temp.macosx-10.9-x86_64-3.8/c-blosc/internal-complibs/lz4-1.8.1.2/lz4hc.o -DSHUFFLE_SSE2_ENABLED -msse2
#   gcc -Wno-unused-result -Wsign-compare -Wunreachable-code -DNDEBUG -g -fwrapv -O3 -Wall -Wstrict-prototypes -I/Users/Dips-Bootcamp/opt/anaconda3/envs/pyvizenv/include -arch x86_64 -I/Users/Dips-Bootcamp/opt/anaconda3/envs/pyvizenv/include -arch x86_64 -DHAVE_LZ4=1 -DHAVE_SNAPPY=1 -DHAVE_ZLIB=1 -DHAVE_ZSTD=1 -Ibcolz -Ic-blosc/blosc -Ic-blosc/internal-complibs/zstd-1.3.4 -Ic-blosc/internal-complibs/lz4-1.8.1.2 -Ic-blosc/internal-complibs/snappy-1.1.1 -Ic-blosc/internal-complibs/zlib-1.2.8 -Ic-blosc/internal-complibs/zstd-1.3.4/compress -Ic-blosc/internal-complibs/zstd-1.3.4/dictBuilder -Ic-blosc/internal-complibs/zstd-1.3.4/decompress -Ic-blosc/internal-complibs/zstd-1.3.4/legacy -Ic-blosc/internal-complibs/zstd-1.3.4/common -Ic-blosc/internal-complibs/zstd-1.3.4/dll -Ic-blosc/internal-complibs/zstd-1.3.4/deprecated -I/Users/Dips-Bootcamp/opt/anaconda3/envs/pyvizenv/lib/python3.8/site-packages/numpy/core/include -I/Users/Dips-Bootcamp/opt/anaconda3/envs/pyvizenv/include/python3.8 -c c-blosc/internal-complibs/lz4-1.8.1.2/lz4.c -o build/temp.macosx-10.9-x86_64-3.8/c-blosc/internal-complibs/lz4-1.8.1.2/lz4.o -DSHUFFLE_SSE2_ENABLED -msse2
#   gcc -Wno-unused-result -Wsign-compare -Wunreachable-code -DNDEBUG -g -fwrapv -O3 -Wall -Wstrict-prototypes -I/Users/Dips-Bootcamp/opt/anaconda3/envs/pyvizenv/include -arch x86_64 -I/Users/Dips-Bootcamp/opt/anaconda3/envs/pyvizenv/include -arch x86_64 -DHAVE_LZ4=1 -DHAVE_SNAPPY=1 -DHAVE_ZLIB=1 -DHAVE_ZSTD=1 -Ibcolz -Ic-blosc/blosc -Ic-blosc/internal-complibs/zstd-1.3.4 -Ic-blosc/internal-complibs/lz4-1.8.1.2 -Ic-blosc/internal-complibs/snappy-1.1.1 -Ic-blosc/internal-complibs/zlib-1.2.8 -Ic-blosc/internal-complibs/zstd-1.3.4/compress -Ic-blosc/internal-complibs/zstd-1.3.4/dictBuilder -Ic-blosc/internal-complibs/zstd-1.3.4/decompress -Ic-blosc/internal-complibs/zstd-1.3.4/legacy -Ic-blosc/internal-complibs/zstd-1.3.4/common -Ic-blosc/internal-complibs/zstd-1.3.4/dll -Ic-blosc/internal-complibs/zstd-1.3.4/deprecated -I/Users/Dips-Bootcamp/opt/anaconda3/envs/pyvizenv/lib/python3.8/site-packages/numpy/core/include -I/Users/Dips-Bootcamp/opt/anaconda3/envs/pyvizenv/include/python3.8 -c c-blosc/internal-complibs/snappy-1.1.1/snappy-stubs-internal.cc -o build/temp.macosx-10.9-x86_64-3.8/c-blosc/internal-complibs/snappy-1.1.1/snappy-stubs-internal.o -DSHUFFLE_SSE2_ENABLED -msse2
#   gcc -Wno-unused-result -Wsign-compare -Wunreachable-code -DNDEBUG -g -fwrapv -O3 -Wall -Wstrict-prototypes -I/Users/Dips-Bootcamp/opt/anaconda3/envs/pyvizenv/include -arch x86_64 -I/Users/Dips-Bootcamp/opt/anaconda3/envs/pyvizenv/include -arch x86_64 -DHAVE_LZ4=1 -DHAVE_SNAPPY=1 -DHAVE_ZLIB=1 -DHAVE_ZSTD=1 -Ibcolz -Ic-blosc/blosc -Ic-blosc/internal-complibs/zstd-1.3.4 -Ic-blosc/internal-complibs/lz4-1.8.1.2 -Ic-blosc/internal-complibs/snappy-1.1.1 -Ic-blosc/internal-complibs/zlib-1.2.8 -Ic-blosc/internal-complibs/zstd-1.3.4/compress -Ic-blosc/internal-complibs/zstd-1.3.4/dictBuilder -Ic-blosc/internal-complibs/zstd-1.3.4/decompress -Ic-blosc/internal-complibs/zstd-1.3.4/legacy -Ic-blosc/internal-complibs/zstd-1.3.4/common -Ic-blosc/internal-complibs/zstd-1.3.4/dll -Ic-blosc/internal-complibs/zstd-1.3.4/deprecated -I/Users/Dips-Bootcamp/opt/anaconda3/envs/pyvizenv/lib/python3.8/site-packages/numpy/core/include -I/Users/Dips-Bootcamp/opt/anaconda3/envs/pyvizenv/include/python3.8 -c c-blosc/internal-complibs/snappy-1.1.1/snappy-c.cc -o build/temp.macosx-10.9-x86_64-3.8/c-blosc/internal-complibs/snappy-1.1.1/snappy-c.o -DSHUFFLE_SSE2_ENABLED -msse2
#   gcc -Wno-unused-result -Wsign-compare -Wunreachable-code -DNDEBUG -g -fwrapv -O3 -Wall -Wstrict-prototypes -I/Users/Dips-Bootcamp/opt/anaconda3/envs/pyvizenv/include -arch x86_64 -I/Users/Dips-Bootcamp/opt/anaconda3/envs/pyvizenv/include -arch x86_64 -DHAVE_LZ4=1 -DHAVE_SNAPPY=1 -DHAVE_ZLIB=1 -DHAVE_ZSTD=1 -Ibcolz -Ic-blosc/blosc -Ic-blosc/internal-complibs/zstd-1.3.4 -Ic-blosc/internal-complibs/lz4-1.8.1.2 -Ic-blosc/internal-complibs/snappy-1.1.1 -Ic-blosc/internal-complibs/zlib-1.2.8 -Ic-blosc/internal-complibs/zstd-1.3.4/compress -Ic-blosc/internal-complibs/zstd-1.3.4/dictBuilder -Ic-blosc/internal-complibs/zstd-1.3.4/decompress -Ic-blosc/internal-complibs/zstd-1.3.4/legacy -Ic-blosc/internal-complibs/zstd-1.3.4/common -Ic-blosc/internal-complibs/zstd-1.3.4/dll -Ic-blosc/internal-complibs/zstd-1.3.4/deprecated -I/Users/Dips-Bootcamp/opt/anaconda3/envs/pyvizenv/lib/python3.8/site-packages/numpy/core/include -I/Users/Dips-Bootcamp/opt/anaconda3/envs/pyvizenv/include/python3.8 -c c-blosc/internal-complibs/snappy-1.1.1/snappy-sinksource.cc -o build/temp.macosx-10.9-x86_64-3.8/c-blosc/internal-complibs/snappy-1.1.1/snappy-sinksource.o -DSHUFFLE_SSE2_ENABLED -msse2
#   gcc -Wno-unused-result -Wsign-compare -Wunreachable-code -DNDEBUG -g -fwrapv -O3 -Wall -Wstrict-prototypes -I/Users/Dips-Bootcamp/opt/anaconda3/envs/pyvizenv/include -arch x86_64 -I/Users/Dips-Bootcamp/opt/anaconda3/envs/pyvizenv/include -arch x86_64 -DHAVE_LZ4=1 -DHAVE_SNAPPY=1 -DHAVE_ZLIB=1 -DHAVE_ZSTD=1 -Ibcolz -Ic-blosc/blosc -Ic-blosc/internal-complibs/zstd-1.3.4 -Ic-blosc/internal-complibs/lz4-1.8.1.2 -Ic-blosc/internal-complibs/snappy-1.1.1 -Ic-blosc/internal-complibs/zlib-1.2.8 -Ic-blosc/internal-complibs/zstd-1.3.4/compress -Ic-blosc/internal-complibs/zstd-1.3.4/dictBuilder -Ic-blosc/internal-complibs/zstd-1.3.4/decompress -Ic-blosc/internal-complibs/zstd-1.3.4/legacy -Ic-blosc/internal-complibs/zstd-1.3.4/common -Ic-blosc/internal-complibs/zstd-1.3.4/dll -Ic-blosc/internal-complibs/zstd-1.3.4/deprecated -I/Users/Dips-Bootcamp/opt/anaconda3/envs/pyvizenv/lib/python3.8/site-packages/numpy/core/include -I/Users/Dips-Bootcamp/opt/anaconda3/envs/pyvizenv/include/python3.8 -c c-blosc/internal-complibs/snappy-1.1.1/snappy.cc -o build/temp.macosx-10.9-x86_64-3.8/c-blosc/internal-complibs/snappy-1.1.1/snappy.o -DSHUFFLE_SSE2_ENABLED -msse2
#   c-blosc/internal-complibs/snappy-1.1.1/snappy.cc:1013:33: warning: comparison of integers of different signs: 'int' and 'const size_t' (aka 'const unsigned long') [-Wsign-compare]
#           if (curr_iov_index_ + 1 >= output_iov_count_) {
#               ~~~~~~~~~~~~~~~~~~~ ^  ~~~~~~~~~~~~~~~~~
#   c-blosc/internal-complibs/snappy-1.1.1/snappy.cc:1095:35: warning: comparison of integers of different signs: 'int' and 'const size_t' (aka 'const unsigned long') [-Wsign-compare]
#             if (curr_iov_index_ + 1 >= output_iov_count_) {
#                 ~~~~~~~~~~~~~~~~~~~ ^  ~~~~~~~~~~~~~~~~~
#   2 warnings generated.
# ...
#   gcc -Wno-unused-result -Wsign-compare -Wunreachable-code -DNDEBUG -g -fwrapv -O3 -Wall -Wstrict-prototypes -I/Users/Dips-Bootcamp/opt/anaconda3/envs/pyvizenv/include -arch x86_64 -I/Users/Dips-Bootcamp/opt/anaconda3/envs/pyvizenv/include -arch x86_64 -DHAVE_LZ4=1 -DHAVE_SNAPPY=1 -DHAVE_ZLIB=1 -DHAVE_ZSTD=1 -Ibcolz -Ic-blosc/blosc -Ic-blosc/internal-complibs/zstd-1.3.4 -Ic-blosc/internal-complibs/lz4-1.8.1.2 -Ic-blosc/internal-complibs/snappy-1.1.1 -Ic-blosc/internal-complibs/zlib-1.2.8 -Ic-blosc/internal-complibs/zstd-1.3.4/compress -Ic-blosc/internal-complibs/zstd-1.3.4/dictBuilder -Ic-blosc/internal-complibs/zstd-1.3.4/decompress -Ic-blosc/internal-complibs/zstd-1.3.4/legacy -Ic-blosc/internal-complibs/zstd-1.3.4/common -Ic-blosc/internal-complibs/zstd-1.3.4/dll -Ic-blosc/internal-complibs/zstd-1.3.4/deprecated -I/Users/Dips-Bootcamp/opt/anaconda3/envs/pyvizenv/lib/python3.8/site-packages/numpy/core/include -I/Users/Dips-Bootcamp/opt/anaconda3/envs/pyvizenv/include/python3.8 -c c-blosc/internal-complibs/zlib-1.2.8/gzlib.c -o build/temp.macosx-10.9-x86_64-3.8/c-blosc/internal-complibs/zlib-1.2.8/gzlib.o -DSHUFFLE_SSE2_ENABLED -msse2
#   c-blosc/internal-complibs/zlib-1.2.8/gzlib.c:256:24: warning: implicit declaration of function 'lseek' is invalid in C99 [-Wimplicit-function-declaration]
#           state->start = LSEEK(state->fd, 0, SEEK_CUR);
#                          ^
#   c-blosc/internal-complibs/zlib-1.2.8/gzlib.c:14:17: note: expanded from macro 'LSEEK'
#   #  define LSEEK lseek
#                   ^
#   c-blosc/internal-complibs/zlib-1.2.8/gzlib.c:256:24: warning: this function declaration is not a prototype [-Wstrict-prototypes]
#   c-blosc/internal-complibs/zlib-1.2.8/gzlib.c:14:17: note: expanded from macro 'LSEEK'
#   #  define LSEEK lseek
#                   ^
#   c-blosc/internal-complibs/zlib-1.2.8/gzlib.c:355:9: warning: implicit declaration of function 'lseek' is invalid in C99 [-Wimplicit-function-declaration]
#       if (LSEEK(state->fd, state->start, SEEK_SET) == -1)
#           ^
#   c-blosc/internal-complibs/zlib-1.2.8/gzlib.c:14:17: note: expanded from macro 'LSEEK'
#   #  define LSEEK lseek
#                   ^
#   c-blosc/internal-complibs/zlib-1.2.8/gzlib.c:396:15: warning: implicit declaration of function 'lseek' is invalid in C99 [-Wimplicit-function-declaration]
#           ret = LSEEK(state->fd, offset - state->x.have, SEEK_CUR);
#                 ^
#   c-blosc/internal-complibs/zlib-1.2.8/gzlib.c:14:17: note: expanded from macro 'LSEEK'
#   #  define LSEEK lseek
#                   ^
#   c-blosc/internal-complibs/zlib-1.2.8/gzlib.c:492:14: warning: implicit declaration of function 'lseek' is invalid in C99 [-Wimplicit-function-declaration]
#       offset = LSEEK(state->fd, 0, SEEK_CUR);
#                ^
#   c-blosc/internal-complibs/zlib-1.2.8/gzlib.c:14:17: note: expanded from macro 'LSEEK'
#   #  define LSEEK lseek
#                   ^
#   5 warnings generated.
#   gcc -Wno-unused-result -Wsign-compare -Wunreachable-code -DNDEBUG -g -fwrapv -O3 -Wall -Wstrict-prototypes -I/Users/Dips-Bootcamp/opt/anaconda3/envs/pyvizenv/include -arch x86_64 -I/Users/Dips-Bootcamp/opt/anaconda3/envs/pyvizenv/include -arch x86_64 -DHAVE_LZ4=1 -DHAVE_SNAPPY=1 -DHAVE_ZLIB=1 -DHAVE_ZSTD=1 -Ibcolz -Ic-blosc/blosc -Ic-blosc/internal-complibs/zstd-1.3.4 -Ic-blosc/internal-complibs/lz4-1.8.1.2 -Ic-blosc/internal-complibs/snappy-1.1.1 -Ic-blosc/internal-complibs/zlib-1.2.8 -Ic-blosc/internal-complibs/zstd-1.3.4/compress -Ic-blosc/internal-complibs/zstd-1.3.4/dictBuilder -Ic-blosc/internal-complibs/zstd-1.3.4/decompress -Ic-blosc/internal-complibs/zstd-1.3.4/legacy -Ic-blosc/internal-complibs/zstd-1.3.4/common -Ic-blosc/internal-complibs/zstd-1.3.4/dll -Ic-blosc/internal-complibs/zstd-1.3.4/deprecated -I/Users/Dips-Bootcamp/opt/anaconda3/envs/pyvizenv/lib/python3.8/site-packages/numpy/core/include -I/Users/Dips-Bootcamp/opt/anaconda3/envs/pyvizenv/include/python3.8 -c c-blosc/internal-complibs/zlib-1.2.8/inftrees.c -o build/temp.macosx-10.9-x86_64-3.8/c-blosc/internal-complibs/zlib-1.2.8/inftrees.o -DSHUFFLE_SSE2_ENABLED -msse2
#   gcc -Wno-unused-result -Wsign-compare -Wunreachable-code -DNDEBUG -g -fwrapv -O3 -Wall -Wstrict-prototypes -I/Users/Dips-Bootcamp/opt/anaconda3/envs/pyvizenv/include -arch x86_64 -I/Users/Dips-Bootcamp/opt/anaconda3/envs/pyvizenv/include -arch x86_64 -DHAVE_LZ4=1 -DHAVE_SNAPPY=1 -DHAVE_ZLIB=1 -DHAVE_ZSTD=1 -Ibcolz -Ic-blosc/blosc -Ic-blosc/internal-complibs/zstd-1.3.4 -Ic-blosc/internal-complibs/lz4-1.8.1.2 -Ic-blosc/internal-complibs/snappy-1.1.1 -Ic-blosc/internal-complibs/zlib-1.2.8 -Ic-blosc/internal-complibs/zstd-1.3.4/compress -Ic-blosc/internal-complibs/zstd-1.3.4/dictBuilder -Ic-blosc/internal-complibs/zstd-1.3.4/decompress -Ic-blosc/internal-complibs/zstd-1.3.4/legacy -Ic-blosc/internal-complibs/zstd-1.3.4/common -Ic-blosc/internal-complibs/zstd-1.3.4/dll -Ic-blosc/internal-complibs/zstd-1.3.4/deprecated -I/Users/Dips-Bootcamp/opt/anaconda3/envs/pyvizenv/lib/python3.8/site-packages/numpy/core/include -I/Users/Dips-Bootcamp/opt/anaconda3/envs/pyvizenv/include/python3.8 -c c-blosc/internal-complibs/zlib-1.2.8/uncompr.c -o build/temp.macosx-10.9-x86_64-3.8/c-blosc/internal-complibs/zlib-1.2.8/uncompr.o -DSHUFFLE_SSE2_ENABLED -msse2
#   gcc -Wno-unused-result -Wsign-compare -Wunreachable-code -DNDEBUG -g -fwrapv -O3 -Wall -Wstrict-prototypes -I/Users/Dips-Bootcamp/opt/anaconda3/envs/pyvizenv/include -arch x86_64 -I/Users/Dips-Bootcamp/opt/anaconda3/envs/pyvizenv/include -arch x86_64 -DHAVE_LZ4=1 -DHAVE_SNAPPY=1 -DHAVE_ZLIB=1 -DHAVE_ZSTD=1 -Ibcolz -Ic-blosc/blosc -Ic-blosc/internal-complibs/zstd-1.3.4 -Ic-blosc/internal-complibs/lz4-1.8.1.2 -Ic-blosc/internal-complibs/snappy-1.1.1 -Ic-blosc/internal-complibs/zlib-1.2.8 -Ic-blosc/internal-complibs/zstd-1.3.4/compress -Ic-blosc/internal-complibs/zstd-1.3.4/dictBuilder -Ic-blosc/internal-complibs/zstd-1.3.4/decompress -Ic-blosc/internal-complibs/zstd-1.3.4/legacy -Ic-blosc/internal-complibs/zstd-1.3.4/common -Ic-blosc/internal-complibs/zstd-1.3.4/dll -Ic-blosc/internal-complibs/zstd-1.3.4/deprecated -I/Users/Dips-Bootcamp/opt/anaconda3/envs/pyvizenv/lib/python3.8/site-packages/numpy/core/include -I/Users/Dips-Bootcamp/opt/anaconda3/envs/pyvizenv/include/python3.8 -c c-blosc/internal-complibs/zlib-1.2.8/gzwrite.c -o build/temp.macosx-10.9-x86_64-3.8/c-blosc/internal-complibs/zlib-1.2.8/gzwrite.o -DSHUFFLE_SSE2_ENABLED -msse2
#   c-blosc/internal-complibs/zlib-1.2.8/gzwrite.c:84:15: warning: implicit declaration of function 'write' is invalid in C99 [-Wimplicit-function-declaration]
#           got = write(state->fd, strm->next_in, strm->avail_in);
#                 ^
#   c-blosc/internal-complibs/zlib-1.2.8/gzwrite.c:84:15: warning: this function declaration is not a prototype [-Wstrict-prototypes]
#   c-blosc/internal-complibs/zlib-1.2.8/gzwrite.c:101:33: warning: implicit declaration of function 'write' is invalid in C99 [-Wimplicit-function-declaration]
#               if (have && ((got = write(state->fd, state->x.next, have)) < 0 ||
#                                   ^
#   c-blosc/internal-complibs/zlib-1.2.8/gzwrite.c:573:9: warning: implicit declaration of function 'close' is invalid in C99 [-Wimplicit-function-declaration]
#       if (close(state->fd) == -1)
#           ^
#   c-blosc/internal-complibs/zlib-1.2.8/gzwrite.c:573:9: warning: this function declaration is not a prototype [-Wstrict-prototypes]
#   5 warnings generated.
#   gcc -Wno-unused-result -Wsign-compare -Wunreachable-code -DNDEBUG -g -fwrapv -O3 -Wall -Wstrict-prototypes -I/Users/Dips-Bootcamp/opt/anaconda3/envs/pyvizenv/include -arch x86_64 -I/Users/Dips-Bootcamp/opt/anaconda3/envs/pyvizenv/include -arch x86_64 -DHAVE_LZ4=1 -DHAVE_SNAPPY=1 -DHAVE_ZLIB=1 -DHAVE_ZSTD=1 -Ibcolz -Ic-blosc/blosc -Ic-blosc/internal-complibs/zstd-1.3.4 -Ic-blosc/internal-complibs/lz4-1.8.1.2 -Ic-blosc/internal-complibs/snappy-1.1.1 -Ic-blosc/internal-complibs/zlib-1.2.8 -Ic-blosc/internal-complibs/zstd-1.3.4/compress -Ic-blosc/internal-complibs/zstd-1.3.4/dictBuilder -Ic-blosc/internal-complibs/zstd-1.3.4/decompress -Ic-blosc/internal-complibs/zstd-1.3.4/legacy -Ic-blosc/internal-complibs/zstd-1.3.4/common -Ic-blosc/internal-complibs/zstd-1.3.4/dll -Ic-blosc/internal-complibs/zstd-1.3.4/deprecated -I/Users/Dips-Bootcamp/opt/anaconda3/envs/pyvizenv/lib/python3.8/site-packages/numpy/core/include -I/Users/Dips-Bootcamp/opt/anaconda3/envs/pyvizenv/include/python3.8 -c c-blosc/internal-complibs/zlib-1.2.8/trees.c -o build/temp.macosx-10.9-x86_64-3.8/c-blosc/internal-complibs/zlib-1.2.8/trees.o -DSHUFFLE_SSE2_ENABLED -msse2
#   gcc -Wno-unused-result -Wsign-compare -Wunreachable-code -DNDEBUG -g -fwrapv -O3 -Wall -Wstrict-prototypes -I/Users/Dips-Bootcamp/opt/anaconda3/envs/pyvizenv/include -arch x86_64 -I/Users/Dips-Bootcamp/opt/anaconda3/envs/pyvizenv/include -arch x86_64 -DHAVE_LZ4=1 -DHAVE_SNAPPY=1 -DHAVE_ZLIB=1 -DHAVE_ZSTD=1 -Ibcolz -Ic-blosc/blosc -Ic-blosc/internal-complibs/zstd-1.3.4 -Ic-blosc/internal-complibs/lz4-1.8.1.2 -Ic-blosc/internal-complibs/snappy-1.1.1 -Ic-blosc/internal-complibs/zlib-1.2.8 -Ic-blosc/internal-complibs/zstd-1.3.4/compress -Ic-blosc/internal-complibs/zstd-1.3.4/dictBuilder -Ic-blosc/internal-complibs/zstd-1.3.4/decompress -Ic-blosc/internal-complibs/zstd-1.3.4/legacy -Ic-blosc/internal-complibs/zstd-1.3.4/common -Ic-blosc/internal-complibs/zstd-1.3.4/dll -Ic-blosc/internal-complibs/zstd-1.3.4/deprecated -I/Users/Dips-Bootcamp/opt/anaconda3/envs/pyvizenv/lib/python3.8/site-packages/numpy/core/include -I/Users/Dips-Bootcamp/opt/anaconda3/envs/pyvizenv/include/python3.8 -c c-blosc/internal-complibs/zlib-1.2.8/gzclose.c -o build/temp.macosx-10.9-x86_64-3.8/c-blosc/internal-complibs/zlib-1.2.8/gzclose.o -DSHUFFLE_SSE2_ENABLED -msse2
#   gcc -Wno-unused-result -Wsign-compare -Wunreachable-code -DNDEBUG -g -fwrapv -O3 -Wall -Wstrict-prototypes -I/Users/Dips-Bootcamp/opt/anaconda3/envs/pyvizenv/include -arch x86_64 -I/Users/Dips-Bootcamp/opt/anaconda3/envs/pyvizenv/include -arch x86_64 -DHAVE_LZ4=1 -DHAVE_SNAPPY=1 -DHAVE_ZLIB=1 -DHAVE_ZSTD=1 -Ibcolz -Ic-blosc/blosc -Ic-blosc/internal-complibs/zstd-1.3.4 -Ic-blosc/internal-complibs/lz4-1.8.1.2 -Ic-blosc/internal-complibs/snappy-1.1.1 -Ic-blosc/internal-complibs/zlib-1.2.8 -Ic-blosc/internal-complibs/zstd-1.3.4/compress -Ic-blosc/internal-complibs/zstd-1.3.4/dictBuilder -Ic-blosc/internal-complibs/zstd-1.3.4/decompress -Ic-blosc/internal-complibs/zstd-1.3.4/legacy -Ic-blosc/internal-complibs/zstd-1.3.4/common -Ic-blosc/internal-complibs/zstd-1.3.4/dll -Ic-blosc/internal-complibs/zstd-1.3.4/deprecated -I/Users/Dips-Bootcamp/opt/anaconda3/envs/pyvizenv/lib/python3.8/site-packages/numpy/core/include -I/Users/Dips-Bootcamp/opt/anaconda3/envs/pyvizenv/include/python3.8 -c c-blosc/internal-complibs/zlib-1.2.8/inffast.c -o build/temp.macosx-10.9-x86_64-3.8/c-blosc/internal-complibs/zlib-1.2.8/inffast.o -DSHUFFLE_SSE2_ENABLED -msse2
#   gcc -Wno-unused-result -Wsign-compare -Wunreachable-code -DNDEBUG -g -fwrapv -O3 -Wall -Wstrict-prototypes -I/Users/Dips-Bootcamp/opt/anaconda3/envs/pyvizenv/include -arch x86_64 -I/Users/Dips-Bootcamp/opt/anaconda3/envs/pyvizenv/include -arch x86_64 -DHAVE_LZ4=1 -DHAVE_SNAPPY=1 -DHAVE_ZLIB=1 -DHAVE_ZSTD=1 -Ibcolz -Ic-blosc/blosc -Ic-blosc/internal-complibs/zstd-1.3.4 -Ic-blosc/internal-complibs/lz4-1.8.1.2 -Ic-blosc/internal-complibs/snappy-1.1.1 -Ic-blosc/internal-complibs/zlib-1.2.8 -Ic-blosc/internal-complibs/zstd-1.3.4/compress -Ic-blosc/internal-complibs/zstd-1.3.4/dictBuilder -Ic-blosc/internal-complibs/zstd-1.3.4/decompress -Ic-blosc/internal-complibs/zstd-1.3.4/legacy -Ic-blosc/internal-complibs/zstd-1.3.4/common -Ic-blosc/internal-complibs/zstd-1.3.4/dll -Ic-blosc/internal-complibs/zstd-1.3.4/deprecated -I/Users/Dips-Bootcamp/opt/anaconda3/envs/pyvizenv/lib/python3.8/site-packages/numpy/core/include -I/Users/Dips-Bootcamp/opt/anaconda3/envs/pyvizenv/include/python3.8 -c c-blosc/internal-complibs/zlib-1.2.8/adler32.c -o build/temp.macosx-10.9-x86_64-3.8/c-blosc/internal-complibs/zlib-1.2.8/adler32.o -DSHUFFLE_SSE2_ENABLED -msse2
#   gcc -Wno-unused-result -Wsign-compare -Wunreachable-code -DNDEBUG -g -fwrapv -O3 -Wall -Wstrict-prototypes -I/Users/Dips-Bootcamp/opt/anaconda3/envs/pyvizenv/include -arch x86_64 -I/Users/Dips-Bootcamp/opt/anaconda3/envs/pyvizenv/include -arch x86_64 -DHAVE_LZ4=1 -DHAVE_SNAPPY=1 -DHAVE_ZLIB=1 -DHAVE_ZSTD=1 -Ibcolz -Ic-blosc/blosc -Ic-blosc/internal-complibs/zstd-1.3.4 -Ic-blosc/internal-complibs/lz4-1.8.1.2 -Ic-blosc/internal-complibs/snappy-1.1.1 -Ic-blosc/internal-complibs/zlib-1.2.8 -Ic-blosc/internal-complibs/zstd-1.3.4/compress -Ic-blosc/internal-complibs/zstd-1.3.4/dictBuilder -Ic-blosc/internal-complibs/zstd-1.3.4/decompress -Ic-blosc/internal-complibs/zstd-1.3.4/legacy -Ic-blosc/internal-complibs/zstd-1.3.4/common -Ic-blosc/internal-complibs/zstd-1.3.4/dll -Ic-blosc/internal-complibs/zstd-1.3.4/deprecated -I/Users/Dips-Bootcamp/opt/anaconda3/envs/pyvizenv/lib/python3.8/site-packages/numpy/core/include -I/Users/Dips-Bootcamp/opt/anaconda3/envs/pyvizenv/include/python3.8 -c c-blosc/internal-complibs/zstd-1.3.4/compress/zstdmt_compress.c -o build/temp.macosx-10.9-x86_64-3.8/c-blosc/internal-complibs/zstd-1.3.4/compress/zstdmt_compress.o -DSHUFFLE_SSE2_ENABLED -msse2
#   c-blosc/internal-complibs/zstd-1.3.4/compress/zstdmt_compress.c:113:9: warning: code will never be executed [-Wunreachable-code]
#           ZSTD_free(bufPool, cMem);
#           ^~~~~~~~~
#   c-blosc/internal-complibs/zstd-1.3.4/compress/zstdmt_compress.c:346:9: warning: code will never be executed [-Wunreachable-code]
#           ZSTD_free(cctxPool, cMem);
#           ^~~~~~~~~
#   c-blosc/internal-complibs/zstd-1.3.4/compress/zstdmt_compress.c:633:45: warning: implicit declaration of function 'ZSTD_CCtxParam_setParameter' is invalid in C99 [-Wimplicit-function-declaration]
#           {   size_t const forceWindowError = ZSTD_CCtxParam_setParameter(&jobParams, ZSTD_p_forceMaxWindow, !job->firstJob);
#                                               ^
#   c-blosc/internal-complibs/zstd-1.3.4/compress/zstdmt_compress.c:633:45: warning: this function declaration is not a prototype [-Wstrict-prototypes]
#   c-blosc/internal-complibs/zstd-1.3.4/compress/zstdmt_compress.c:633:85: error: use of undeclared identifier 'ZSTD_p_forceMaxWindow'
#           {   size_t const forceWindowError = ZSTD_CCtxParam_setParameter(&jobParams, ZSTD_p_forceMaxWindow, !job->firstJob);
#                                                                                       ^
#   4 warnings and 1 error generated.
#   error: command 'gcc' failed with exit status 1
#   ----------------------------------------
#   ERROR: Failed building wheel for bcolz
#   Running setup.py clean for bcolz
#   Building wheel for feather-format (setup.py) ... done
#   Created wheel for feather-format: filename=feather_format-0.4.1-py3-none-any.whl size=2453 sha256=7bd07d55e8401b78acb8d32dccb792213565c18c062dd88f654ec77e806fc33f
#   Stored in directory: /Users/Dips-Bootcamp/Library/Caches/pip/wheels/7b/83/4b/44aa8f2292c0ae17a550c5105454e974fc45a5b2a522d66ae1
#   Building wheel for opencv-python (PEP 517) ... /
